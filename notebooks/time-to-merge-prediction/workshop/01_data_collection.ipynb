# %% [markdown]
# # Pull Requests Data Collection
#
# In this notebook, we will collect the raw Pull Request data from a github repo of choice, and save it as a json file on an s3 bucket. To do this, we will use the `srcopsmetrics` tool developed by the Thoth team.

# %%
import os

from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %% [markdown]
# ## Set Environment variables
#
# Before you start, make sure to create a .env file at the root of the repository with the required credentials and paths. Refer to workshop section **"Set your Environment Variables"** for details on how to set it and this example [file](env_example_workshop) for the structure.

# %%
# get the org/repo from env vars
ORG = os.getenv("GITHUB_ORG")
REPO = os.getenv("GITHUB_REPO")
CEPH_BUCKET_PREFIX = os.getenv("CEPH_BUCKET_PREFIX")

print(f"{ORG}/{REPO}")
print(
    f"Downloaded file is being stored at {CEPH_BUCKET_PREFIX}/srcopsmetrics/bot_knowledge/{ORG}/{REPO}/PullRequest.json"
)
# Out:
# aicoe-aiops/ocp-ci-analysis
# Downloaded file is being stored at oindrillac/srcopsmetrics/bot_knowledge/aicoe-aiops/ocp-ci-analysis/PullRequest.json

# %%
# run collection on the org/repo specified
# !python -m srcopsmetrics.cli --create-knowledge --repository $ORG/$REPO --entities PullRequest
# Out:
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing aicoe-aiops/ocp-ci-analysis ########################
#
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # ThothAdviseMetrics # ThothMetrics # ThothMetrics # ThothMetrics # ThothVersionManagerMetrics # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge from Ceph
# INFO:srcopsmetrics.entities.interface:Found previous PullRequest knowledge for aicoe-aiops/ocp-ci-analysis with 237 records
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #554
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #553
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #551
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #550
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #549
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #548
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #547
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #544
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #543
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #542
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #541
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #539
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #538
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #537
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #536
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #535
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #534
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #532
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #530
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #522
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #520
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #519
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #518
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #516
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #508
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #507
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #506
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #505
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #501
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #500
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #499
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #498
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #496
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #495
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #494
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #492
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #490
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #487
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #486
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #485
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #484
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #483
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #481
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #478
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #476
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #475
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #474
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #472
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #471
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #470
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #469
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #468
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #467
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #466
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #465
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #464
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #462
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #460
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #458
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #456
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #450
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #448
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #446
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #445
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #444
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #441
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #437
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #435
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #433
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #425
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #424
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #423
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #420
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #415
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #411
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #408
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #405
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #400
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #398
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #397
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #395
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #394
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #392
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #391
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #390
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #389
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #386
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #385
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #383
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #378
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #377
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #375
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #373
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #371
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #370
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #369
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #367
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #366
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #364
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #352
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #351
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #348
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #347
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #342
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #337
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #331
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #328
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #320
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #319
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #317
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #316
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #310
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #309
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #306
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #301
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #297
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #293
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #290
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #289
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #287
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #285
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #284
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #283
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #278
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #277
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #276
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #273
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #270
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #269
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #267
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #265
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #264
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #262
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #257
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #256
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #253
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #251
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #248
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #247
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #245
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #243
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #232
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #231
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #230
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #224
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #216
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #215
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #214
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #212
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #211
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #210
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #209
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #208
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #207
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #206
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #204
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #201
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #200
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #199
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #196
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #195
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #191
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #189
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #188
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #178
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #177
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #174
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #172
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #169
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #168
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #167
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #166
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #163
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #160
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #153
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #152
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #150
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #148
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #142
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #141
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #140
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #133
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #132
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #131
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #130
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #129
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #127
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #122
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #119
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #115
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #113
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #112
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #111
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #103
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #102
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #101
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #100
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #97
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #96
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #93
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #91
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #89
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #79
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #71
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #67
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #66
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #65
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #64
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #63
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #62
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #61
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #59
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #58
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #57
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #53
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #51
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #48
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #47
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #46
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #45
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #44
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #42
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #39
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #38
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #37
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #36
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #31
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #29
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #28
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #27
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #24
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #23
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #16
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #14
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #9
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #6
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #2
# 100%|████████████████████| 237/237 [00:20<00:00, 11.48it/s, RATE remaining=4988]
# INFO:srcopsmetrics.entities.interface:Nothing to store.
# INFO:srcopsmetrics.entities.interface:
#
# INFO:srcopsmetrics.bot_knowledge:

# %% [markdown]
# # Conclusion
#
# By running this notebook we have collected and stored the github PR data to our s3 bucket. It is now ready for the cleaning and feature engineering steps of the ML workflow.
#
# # Next Step
#
# In the next [notebook](./02_feature_engineering.ipynb), we will engineer some features from the raw PR data which can be used to train a ML model
